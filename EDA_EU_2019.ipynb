# %%
import pandas as pd 
import numpy as numpy
import seaborn as sborn

# %%
import matplotlib.pyplot as plt
from matplotlib import rcParams

# %%
df= pd.read_csv("IT Salary Survey EU 2019.csv")

# %%
df.head()
# Out:
#            Zeitstempel   Age Gender    City Seniority level  \
# 0  02.12.2019 11:18:26  33.0   Male  Berlin          Senior
# 1  02.12.2019 11:18:35  29.0   Male  Berlin          Middle
# 2  02.12.2019 11:18:56   NaN   Male  Berlin          Middle
# 3  02.12.2019 11:19:08  30.0   Male  Berlin          Senior
# 4  02.12.2019 11:19:37  32.0   Male  Berlin          Senior
#
#   Position (without seniority)  Years of experience  \
# 0          Fullstack Developer                   13
# 1            Backend Developer                    3
# 2             Mobile Developer                    4
# 3            Backend Developer                    6
# 4           Embedded Developer                   10
#
#   Your main technology / programming language  \
# 0                                         PHP
# 1                                      Python
# 2                                      Kotlin
# 3                                         PHP
# 4                                       C/C++
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 991 entries, 0 to 990
# Data columns (total 23 columns):
#  #   Column                                                                                                Non-Null Count  Dtype
# ---  ------                                                                                                --------------  -----
#  0   Zeitstempel                                                                                           991 non-null    object
#  1   Age                                                                                                   882 non-null    float64
#  2   Gender                                                                                                991 non-null    object
#  3   City                                                                                                  991 non-null    object
# ...

# %%
#obtain shape of dataframe
df.shape
# Out:
# (991, 23)

# %%
#data statical summary
df.describe()
# Out:
#               Age  Years of experience  \
# count  882.000000           991.000000
# mean    32.416100             8.529768
# std      5.262496             5.036320
# min     20.000000             0.000000
# 25%     29.000000             5.000000
# 50%     32.000000             8.000000
# 75%     35.000000            11.000000
# max     54.000000            30.000000
#
#        Yearly brutto salary (without bonus and stocks)  Yearly bonus  \
# count                                       990.000000    530.000000
# mean                                      72562.212121   7857.169811
# std                                       23947.379182  10320.628344
# min                                        6000.000000      0.000000
# 25%                                       60000.000000    300.000000
# 50%                                       70000.000000   5000.000000
# 75%                                       80000.000000  10000.000000
# ...

# %%
df.count()
# Out:
# Zeitstempel                                                                                             991
# Age                                                                                                     882
# Gender                                                                                                  991
# City                                                                                                    991
# Seniority level                                                                                         976
# Position (without seniority)                                                                            990
# Years of experience                                                                                     991
# Your main technology / programming language                                                             977
# Yearly brutto salary (without bonus and stocks)                                                         990
# ...

# %%
df.Age.max()
# Out:
# 54.0

# %%
df.City.unique()
# Out:
# array(['Berlin', 'Hamburg', 'Frankfurt', 'Munich', 'Cologne',
#        'Düsseldorf', 'Wolfsburg', 'MA', 'Leipzig', 'Nuremberg', 'Krakow',
#        'Prague', 'Wroclaw', 'Stuttgart', 'London', 'Karlsruhe',
#        'Ingolstadt', 'Riga', 'Bern', 'Moscow', 'Darmstadt', 'Dusseldorf',
#        'Kyiv', 'Freiburg', 'Amsterdam', 'Vienna', 'Pforzheim', 'Kassel ',
#        'Madrid', 'Marburg', 'Warsaw', 'Hannover', 'Paris', 'Milan',
#        'Odesa', 'Cork', 'Zug', 'Heidelberg', 'Brussels', 'Bielefeld',
#        'Dublin', 'Jyvaskyla', 'Toulouse', 'Dubai', 'Zurich', 'Lingen',
#        'Dresden', 'Lugano', 'Walldorf', 'Schleswig-Holstein',
#        'Braunschweig', 'Kaiserslautern', 'Eindhoven', 'Saint Petersburg',
#        'Eindhoven ', 'Leeuwarden', 'Hilversum', 'Gdańsk', 'Gothenburg',
#        'Almere', 'Limassol', 'Stockholm', 'Tampere', 'Bayern',
#        'Rotterdam', 'Antwerpen', 'Tallinn', 'Koblenz', 'Würzburg ',
#        'Bremen', 'Lausanne', 'Nizhny Novgorod ', 'Saint-Petersburg ',
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 986    False
# 987    False
# 988    False
# 989    False
# 990    False
# Length: 991, dtype: bool

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
#find null values
df.isnull().sum()
# Out:
# Zeitstempel                                                                                               0
# Age                                                                                                     109
# Gender                                                                                                    0
# City                                                                                                      0
# Seniority level                                                                                          15
# Position (without seniority)                                                                              1
# Years of experience                                                                                       0
# Your main technology / programming language                                                              14
# Yearly brutto salary (without bonus and stocks)                                                           1
# ...

# %%
#Replace null values
df.replace(numpy.nan,'0',inplace=True)

# %%
df.dtypes
# Out:
# Zeitstempel                                                                                             object
# Age                                                                                                     object
# Gender                                                                                                  object
# City                                                                                                    object
# Seniority level                                                                                         object
# Position (without seniority)                                                                            object
# Years of experience                                                                                      int64
# Your main technology / programming language                                                             object
# ...

# %%
#Filter data

df[df['Seniority level']=='Junior'].head()
# Out:
#              Zeitstempel   Age  Gender    City Seniority level  \
# 76   02.12.2019 12:43:59  26.0    Male  Munich          Junior
# 115  02.12.2019 14:27:33  46.0    Male  Berlin          Junior
# 134  02.12.2019 15:15:03  45.0  Female  Munich          Junior
# 152  02.12.2019 15:43:54  31.0  Female  Munich          Junior
# 154  02.12.2019 15:44:44  24.0  Female  Munich          Junior
#
#     Position (without seniority)  Years of experience  \
# 76           Fullstack Developer                    2
# 115                       DevOps                    0
# 134           Frontend Developer                    2
# 152          Fullstack Developer                    4
# 154            Backend Developer                    1
#
#     Your main technology / programming language  \
# 76                                         Java
# 115                                  Kubernetes
# 134                                        Java
# 152                                        Java
# ...

# %%
df[df['Gender']=='Female']
# Out:
#              Zeitstempel   Age  Gender       City Seniority level  \
# 44   02.12.2019 11:50:47  38.0  Female     Berlin          Senior
# 56   02.12.2019 12:07:58  31.0  Female         MA          Senior
# 58   02.12.2019 12:08:31  36.0  Female     Munich          Senior
# 64   02.12.2019 12:18:34  27.0  Female     Berlin          Middle
# 77   02.12.2019 12:45:44  32.0  Female     Berlin          Senior
# ..                   ...   ...     ...        ...             ...
# 947  23.12.2019 13:10:31  29.0  Female     Berlin          Middle
# 967  29.12.2019 16:04:33  44.0  Female     Munich          Middle
# 974  02.01.2020 20:21:33  33.0  Female     Berlin          Junior
# 977  03.01.2020 15:01:40  26.0  Female  Amsterdam          Middle
# 985  06.01.2020 13:15:50  32.0  Female  Amsterdam          Senior
#
#     Position (without seniority)  Years of experience  \
# 44                       Manager                   10
# 56             Designer (UI, UX)                   10
# ...

# %%
df[df['Gender']=='Female'].max()
# Out:
# C:\Users\777\AppData\Local\Temp/ipykernel_13820/2705892211.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['Gender']=='Female'].max()
# Zeitstempel                                        29.12.2019 16:04:33
# Gender                                                          Female
# City                                                            Zurich
# Seniority level                                                 Senior
# Position (without seniority)                         Software Engineer
# Years of experience                                                 20
# Your main technology / programming language                      Swift
# Yearly brutto salary (without bonus and stocks)               200000.0
# Main language at work                                          Spanish
# ...

# %%
df[df['Gender']=='Female'].min()
# Out:
# C:\Users\777\AppData\Local\Temp/ipykernel_13820/2588050070.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['Gender']=='Female'].min()
# Zeitstempel                                        02.01.2020 20:21:33
# Gender                                                          Female
# City                                                         Amsterdam
# Seniority level                                                      0
# Position (without seniority)                         Backend Developer
# Years of experience                                                  0
# Your main technology / programming language                       .NET
# Yearly brutto salary (without bonus and stocks)                13200.0
# Main language at work                                          Deutsch
# ...

# %%
df[df['Gender']=='Male'].count()
# Out:
# Zeitstempel                                                                                             838
# Age                                                                                                     838
# Gender                                                                                                  838
# City                                                                                                    838
# Seniority level                                                                                         838
# Position (without seniority)                                                                            838
# Years of experience                                                                                     838
# Your main technology / programming language                                                             838
# Yearly brutto salary (without bonus and stocks)                                                         838
# ...

# %%
df[df['Gender']=='Male'].max()
# Out:
# C:\Users\777\AppData\Local\Temp/ipykernel_13820/3483715428.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['Gender']=='Male'].max()
# Zeitstempel                                    31.12.2019 19:58:17
# Gender                                                        Male
# City                                                        Zurich
# Seniority level                                             Senior
# Position (without seniority)                               support
# Years of experience                                             30
# Your main technology / programming language                   Yaml
# Main language at work                                    Ukrainian
# Company name                                               Яфдфтвщ
# ...

# %%
df[df['Gender']=='Male'].min()
# Out:
# C:\Users\777\AppData\Local\Temp/ipykernel_13820/2802080046.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df[df['Gender']=='Male'].min()
# Zeitstempel                                    01.01.2020 16:52:48
# Gender                                                        Male
# City                                                        Almere
# Seniority level                                                  0
# Position (without seniority)                                     0
# Years of experience                                              0
# Your main technology / programming language                   .NET
# Main language at work                                            0
# Company name                                                     -
# ...

# %%
df.corr()
# Out:
#                      Years of experience
# Years of experience                  1.0

# %%
# Lets move to EDA Of year 2020
df2= pd.read_csv("IT Salary Survey EU  2020.csv")

# %%
df2.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
#dimensions as well as the size in each dimension
df2.shape
# Out:
# (1253, 23)

# %%
df2.size
# Out:
# 28819

# %%
df2.dtypes
# Out:
# Timestamp                                                                                                                   object
# Age                                                                                                                        float64
# Gender                                                                                                                      object
# City                                                                                                                        object
# Position                                                                                                                    object
# Total years of experience                                                                                                   object
# Years of experience in Germany                                                                                              object
# ...

# %%
#data frame dimension
df2.ndim
# Out:
# 2

# %%
df2.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
df.describe()
# Out:
#        Years of experience
# count           991.000000
# mean              8.529768
# std               5.036320
# min               0.000000
# 25%               5.000000
# 50%               8.000000
# 75%              11.000000
# max              30.000000

# %%
df.count()
# Out:
# Zeitstempel                                                                                             991
# Age                                                                                                     991
# Gender                                                                                                  991
# City                                                                                                    991
# Seniority level                                                                                         991
# Position (without seniority)                                                                            991
# Years of experience                                                                                     991
# Your main technology / programming language                                                             991
# Yearly brutto salary (without bonus and stocks)                                                         991
# ...

# %%
df.isnull().sum()
# Out:
# Zeitstempel                                                                                             0
# Age                                                                                                     0
# Gender                                                                                                  0
# City                                                                                                    0
# Seniority level                                                                                         0
# Position (without seniority)                                                                            0
# Years of experience                                                                                     0
# Your main technology / programming language                                                             0
# Yearly brutto salary (without bonus and stocks)                                                         0
# ...

# %%
#quick overview of the dataset
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1253 entries, 0 to 1252
# Data columns (total 23 columns):
#  #   Column                                                                                                                   Non-Null Count  Dtype
# ---  ------                                                                                                                   --------------  -----
#  0   Timestamp                                                                                                                1253 non-null   object
#  1   Age                                                                                                                      1226 non-null   float64
#  2   Gender                                                                                                                   1243 non-null   object
# ...

# %%
#statistical summary for numerical columns present in the dataset
df2.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
df2.sample()
# Out:
#                Timestamp   Age Gender    City          Position   \
# 614  25/11/2020 14:37:25  31.0   Male  Berlin  Software Engineer
#
#     Total years of experience Years of experience in Germany Seniority level  \
# 614                         9                              5            Lead
#
#     Your main technology / programming language  \
# 614                                  javascript
#
#     Other technologies/programming languages you use often  ...  \
# 614                                        AWS, Docker      ...
#
#      Annual bonus+stocks one year ago. Only answer if staying in same country  \
# 614                                              89000
#
#     Number of vacation days   Employment status   Сontract duration  \
# 614                      30  Full-time employee  Unlimited contract
#
#     Main language at work Company size Company type  \
# 614               English     101-1000      Startup
#
# ...

# %%
#number of unique elements
df2.nunique()
# Out:
# Timestamp                                                                                                                  1248
# Age                                                                                                                          40
# Gender                                                                                                                        3
# City                                                                                                                        119
# Position                                                                                                                    148
# Total years of experience                                                                                                    48
# Years of experience in Germany                                                                                               53
# ...

# %%
df2.index
# Out:
# RangeIndex(start=0, stop=1253, step=1)

# %%
#column labels of the dataframe
df2.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %%
#first n rows ordered by columns in descending order
df2.nlargest(7,'Age' )
# Out:
#                 Timestamp   Age Gender        City          Position   \
# 1103  06/12/2020 21:51:21  69.0   Male   Stuttgart            Rentner
# 59    24/11/2020 11:33:51  66.0   Male      Munich  Software Engineer
# 296   24/11/2020 15:39:13  65.0   Male      Berlin  Software Engineer
# 23    24/11/2020 11:23:11  59.0   Male      Berlin  Backend Developer
# 232   24/11/2020 13:53:01  56.0   Male  Ingolstadt  Software Engineer
# 1159  14/12/2020 08:55:24  56.0   Male      Munich  Software Engineer
# 955   30/11/2020 12:56:08  54.0   Male      Milano             Sales
#
#      Total years of experience Years of experience in Germany Seniority level  \
# 1103                       383                              3            Head
# 59                          40                              4            Lead
# 296                         25                             25          Senior
# 23                          30                             30          Senior
# ...

# %%
df2['Gender'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       Male
# 1       Male
# 2       Male
# 3       Male
# 4       Male
#         ...
# 1248    Male
# 1249    Male
# 1250    Male
# 1251    Male
# 1252    Male
# Name: Gender, Length: 1253, dtype: object>

# %%
# find the pairwise correlation of all columns in the dataframe
df2.corr()
# Out:
#                                                          Age  \
# Age                                                 1.000000
# Yearly brutto salary (without bonus and stocks)... -0.017259
# Annual brutto salary (without bonus and stocks)... -0.024847
# Have you been forced to have a shorter working ... -0.003563
#
#                                                     Yearly brutto salary (without bonus and stocks) in EUR  \
# Age                                                                                         -0.017259
# Yearly brutto salary (without bonus and stocks)...                                           1.000000
# Annual brutto salary (without bonus and stocks)...                                           0.999998
# Have you been forced to have a shorter working ...                                          -0.044144
#
# ...

# %%
df2['Age'].value_counts()
# Out:
# 30.0    110
# 33.0     94
# 32.0     94
# 28.0     87
# 31.0     87
# 29.0     86
# 35.0     82
# 34.0     74
# 36.0     60
# 26.0     59
# 27.0     58
# 38.0     48
# 37.0     44
# 25.0     42
# 40.0     31
# 24.0     28
# 39.0     28
# 42.0     20
# 41.0     14
# 23.0     12
# 45.0     11
# 43.0     10
# 22.0      8
# 44.0      8
# 46.0      8
# 48.0      4
# 47.0      3
# 56.0      2
# 49.0      2
# 54.0      2
# 66.0      1
# 53.0      1
# 65.0      1
# 59.0      1
# 50.0      1
# 51.0      1
# 21.0      1
# 20.0      1
# 69.0      1
# 52.0      1
# Name: Age, dtype: int64

# %%
df2.Age.value_counts().plot(kind="bar")
plt.title("Value counts of the Age variable")
plt.xlabel("Age ")
plt.xticks(rotation=0)
plt.ylabel("Count")
plt.show()

# %%
df2.
